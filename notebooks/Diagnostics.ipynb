# %%
import numpy as np
import pandas as pd
import splat
import popsims
from astropy.coordinates import SkyCoord, Galactic,CartesianRepresentation,CartesianDifferential
import astropy.units as u
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
sns.set_style("darkgrid", {"axes.facecolor": ".9"})
sns.set_palette('Set1')
from  matplotlib.colors import Normalize
import matplotlib
# Out:
# /users/caganze/research/splat
#
#
# Welcome to the Spex Prism Library Analysis Toolkit (SPLAT)!
# If you make use of any features of this toolkit for your research, please remember to cite the SPLAT paper:
#
# Burgasser et al. (2017, Astro. Soc. India Conf. Series 14, p. 7); Bibcode: 2017ASInC..14....7B
#
# If you make use of any spectra or models in this toolkit, please remember to cite the original source.
# Please report any errors are feature requests to our github page, https://github.com/aburgasser/splat/

# %%
p = popsims.make_systems()

# %%
np.isclose(2, 2.1, 0.01)
# Out:
# False

# %%
from popsims import galaxy

# %%
#plot velocity dispersion relations
vel=np.arange(10, 20)

# %%
fig, ax=plt.subplots()
ax.plot(vel, galaxy.avr_sharma(vel)[0], c='r')
ax.plot(vel, galaxy.avr_just(vel), c='b')
ax.plot(vel, galaxy.avr_aumer(vel), c='k')
