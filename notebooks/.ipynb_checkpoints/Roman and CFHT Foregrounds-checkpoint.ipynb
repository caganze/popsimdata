# %%
#test the model class on JSWT simulations 
import numpy as np
import pandas as pd
#import splat
#import popsims
from astropy.coordinates import SkyCoord, Galactic
#from popsims.galaxy import Pointing, volume_calc, create_pop
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
#sns.set_style("darkgrid", {"axes.facecolor": ".95"})

#plt.style.use('fivethirtyeight')
#plt.style.use('dark_background')

from  matplotlib.colors import Normalize
import astropy.units as u
import popsims
import matplotlib
from tqdm import tqdm
from tqdm import tqdm
import matplotlib as mpl 
mpl.rcParams['axes.labelsize'] = 20
mpl.rcParams['xtick.labelsize'] =20
mpl.rcParams['ytick.labelsize'] = 20
mpl.rcParams['legend.fontsize'] = 20
mpl.rcParams['figure.titlesize'] = 20

from popsims.simulator import Population,simulate_population
from popsims.galaxy import Disk, Halo
from popsims.relations import polynomial_relation
from popsims.backgrounds import simulate_lsst_background_stars, read_isochrones
from popsims.tools import sample_from_powerlaw
import glob
import scipy.interpolate as interp

# %%
#coordinates for M31
coord=SkyCoord('00 42 44.330 +41 16 07.50', frame="icrs", unit="deg")

# %%
isos
# Out:
#             Zini    MH  logAge      Mini   int_IMF   Mass   logL   logTe  \
# 0       0.000155 -2.00    6.60  0.093634  1.115611  0.094 -1.477  3.5641
# 1       0.000155 -2.00    6.60  0.099765  1.169142  0.100 -1.446  3.5671
# 2       0.000155 -2.00    6.60  0.103569  1.200243  0.103 -1.427  3.5688
# 3       0.000155 -2.00    6.60  0.109037  1.242445  0.109 -1.400  3.5713
# 4       0.000155 -2.00    6.60  0.123439  1.341567  0.123 -1.333  3.5771
# ...          ...   ...     ...       ...       ...    ...    ...     ...
# 134346  0.025095  0.25   10.05  1.044521  2.481780  0.716  3.437  3.4259
# 134347  0.025095  0.25   10.05  1.044521  2.481780  0.706  3.475  3.4196
# 134348  0.025095  0.25   10.05  1.044522  2.481780  0.694  3.489  3.4174
# 134349  0.025095  0.25   10.05  1.044522  2.481781  0.681  3.495  3.4174
# 134350  0.025095  0.25   10.05  1.044524  2.481781  0.529 -9.999  4.0000
#
#          logg  label  ...  F087mag  F106mag  F129mag  F158mag  F184mag  \
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [7], in <cell line: 2>()
#       1 fig, ax=plt.subplots()
# ----> 2 ax.scatter(isos.rmag-isos.zmag, isos.zmag, s=1., marker='+', c= np.log10(isos.Mass), alpha=0.1)
#       3 ax.invert_yaxis()
#       4 ax.set(xlabel='R-Z', ylabel='Z', xlim=[-2, 5], ylim=[20.5, -15])
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5487, in NDFrame.__getattr__(self, name)
#    5480 if (
#    5481     name not in self._internal_names_set
#    5482     and name not in self._metadata
#    5483     and name not in self._accessors
#    5484     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5485 ):
#    5486     return self[name]
# -> 5487 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'rmag'
# ...

# %%
isos.columns

# %%
#this was origanally,

# %%
v= sample_from_isochrones()

# %%
fig, ax=plt.subplots()
ax.scatter(v.r-v.z, v.z, s=1, marker='+')
ax.invert_yaxis()
ax.set(xlabel='R-Z', ylabel='Z', xlim=[-2, 5], ylim=[20.5, -15])

# %%
df

# %%
fig, ax=plt.subplots()
ax.scatter(df.r-df.z, df.z, s=1, marker='+', alpha=0.2)
ax.invert_yaxis()
ax.set(xlabel='r-z', ylabel='z mag', xlim=[-2, 5], ylim=[5, 25.5])

# %%
#ascii.read_(old_isochrone_path='/M31_10_20kpc_new.vot')

# %%
#plot the process from Tjistke's notebook
#read in the pandas data images
df_M31_10_20= pd.read_csv(old_isochrone_path+'/WFIfilters_FromPANDAS_g0limit25.5_ZRcorrection_RAdec_M31_10_20kpc_new.vot.txt', \
                          delim_whitespace=True)

df_M31_30_40= pd.read_csv(old_isochrone_path+'/WFIfilters_FromPANDAS_g0limit25.5_ZRcorrection_RAdec_M31_30_40kpc_new.vot.txt', \
                          delim_whitespace=True)

df_M31_50_60= pd.read_csv(old_isochrone_path+'/WFIfilters_FromPANDAS_g0limit25.5_ZRcorrection_RAdec_M31_50_60kpc_new.vot.txt', \
                          delim_whitespace=True)

# %%
#therere is a limiting magnitude for z
