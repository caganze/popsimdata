# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
u=np.random.uniform(0, 1, 100_000_000)
v=np.random.uniform(0, 1, 100_000_000)
ra=2*np.pi*u
dec= np.arccos(2*v-1)-np.pi/2

# %%
from astropy.coordinates import SkyCoord
from astropy.table import Table
from astropy.io import fits
import astropy.units as u
from tqdm import tqdm

coord=SkyCoord(ra=ra*u.radian, dec=dec*u.radian)

# %%
#save into a table and cross-match with the query

# %%
t=Table()
t['ra']= coord.ra
t['dec']=coord.dec

# %%
#t.write('/users/caganze/uniform_coord.fits', overwrite=True)

# %%
#hj

# %%
#t=fits.open('/users/caganze/uniform_coord.fits')

# %%
import pandas as pd

# %%
f= pd.read_hdf('/volumes/LaCie/popsimsdata/spectral_templates_data.h5', key='singles')
# Out:
# /users/caganze/research/splat
#
#
# Welcome to the Spex Prism Library Analysis Toolkit (SPLAT)!
# If you make use of any features of this toolkit for your research, please remember to cite the SPLAT paper:
#
# Burgasser et al. (2017, Astro. Soc. India Conf. Series 14, p. 7); Bibcode: 2017ASInC..14....7B
#
# If you make use of any spectra or models in this toolkit, please remember to cite the original source.
# Please report any errors are feature requests to our github page, https://github.com/aburgasser/splat/

# %%
f.spectra.values
# Out:
# array([SPEX-PRISM spectrum of 2MASS J16002535-2644060,
#        SPEX-PRISM spectrum of 2MASS J17252029-0024508,
#        SPEX-PRISM spectrum of 2MASS J01532750+3631482,
#        SPEX-PRISM spectrum of WISE J141143.25-452418.3,
#        SPEX-PRISM spectrum of 2MASS J19445221-0831036,
#        SPEX-PRISM spectrum of 2MASS J00013044+1010146,
#        SPEX-PRISM spectrum of 2MASS J01405263+0453302,
#        SPEX-PRISM spectrum of 2MASS J11304030+1206306,
#        SPEX-PRISM spectrum of 2MASS J22465014-0643357,
#        SPEX-PRISM spectrum of 2MASS J15501958-2805237,
#        SPEX-PRISM spectrum of LHS 1375,
#        SPEX-PRISM spectrum of 2MASS J16005265-2812087,
#        SPEX-PRISM spectrum of 2MASS J15544486-2843078,
#        SPEX-PRISM spectrum of 2MASS J15572692-2715094,
#        SPEX-PRISM spectrum of 2MASS J15490803-2839550,
#        SPEX-PRISM spectrum of 2MASS J15524857-2621453,
#        SPEX-PRISM spectrum of 2MASS J15493660-2815141,
# ...

# %%
f
# Out:
#                  spectral_type  \
# 0                  (16.0, 0.5)
# 1    (12.0, 1.118033988749895)
# 2                  (15.0, 0.5)
# 3                  (17.0, 0.5)
# 4    (13.0, 1.118033988749895)
# ..                         ...
# 468                (40.0, 0.5)
# 469                (40.0, 0.5)
# 470  (40.0, 1.118033988749895)
# 471                (38.0, 0.5)
# 472                (39.0, 0.5)
#
#                                              spectra  \
# 0     SPEX-PRISM spectrum of 2MASS J16002535-2644060
# 1     SPEX-PRISM spectrum of 2MASS J17252029-0024508
# 2     SPEX-PRISM spectrum of 2MASS J01532750+3631482
# 3    SPEX-PRISM spectrum of WISE J141143.25-452418.3
# 4     SPEX-PRISM spectrum of 2MASS J19445221-0831036
# ..                                               ...
# 468                                    anon spectrum
# 469                                    anon spectrum
# 470                                    anon spectrum
# ...
